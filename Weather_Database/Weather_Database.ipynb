# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
#Import the datetime module from the datetime library.
from datetime import datetime
import time

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | te anau
# Processing Record 2 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 16 | ushuaia
# Processing Record 4 of Set 16 | nabire
# Processing Record 5 of Set 16 | hasaki
# Processing Record 6 of Set 16 | derzhavinsk
# Processing Record 7 of Set 16 | ribeira grande
# Processing Record 8 of Set 16 | barrow
# Processing Record 9 of Set 16 | cape town
# Processing Record 10 of Set 16 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 16 | qaanaaq
# Processing Record 12 of Set 16 | norman wells
# Processing Record 13 of Set 16 | bredasdorp
# Processing Record 14 of Set 16 | ocampo
# Processing Record 15 of Set 16 | carbonear
# Processing Record 16 of Set 16 | bwanga
# Processing Record 17 of Set 16 | provideniya
# Processing Record 18 of Set 16 | yirol
# City not found. Skipping...
# Processing Record 19 of Set 16 | klaksvik
# Processing Record 20 of Set 16 | tiksi
# Processing Record 21 of Set 16 | kodiak
# Processing Record 22 of Set 16 | kloulklubed
# Processing Record 23 of Set 16 | busselton
# Processing Record 24 of Set 16 | codrington
# Processing Record 25 of Set 16 | quelimane
# Processing Record 26 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 16 | adrar
# Processing Record 28 of Set 16 | bilibino
# Processing Record 29 of Set 16 | portland
# Processing Record 30 of Set 16 | tura
# Processing Record 31 of Set 16 | ixtapa
# Processing Record 32 of Set 16 | vaini
# Processing Record 33 of Set 16 | katsuura
# Processing Record 34 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 16 | fare
# Processing Record 36 of Set 16 | bluff
# Processing Record 37 of Set 16 | chuy
# Processing Record 38 of Set 16 | kulhudhuffushi
# Processing Record 39 of Set 16 | kaitangata
# Processing Record 40 of Set 16 | saint-philippe
# Processing Record 41 of Set 16 | jay
# Processing Record 42 of Set 16 | sawtell
# Processing Record 43 of Set 16 | ambilobe
# Processing Record 44 of Set 16 | new norfolk
# Processing Record 45 of Set 16 | pullman
# Processing Record 46 of Set 16 | albany
# Processing Record 47 of Set 16 | teguise
# Processing Record 48 of Set 16 | hermanus
# Processing Record 49 of Set 16 | chernyshevskiy
# Processing Record 50 of Set 16 | zilair
# Processing Record 1 of Set 17 | graaff-reinet
# Processing Record 2 of Set 17 | acapulco
# Processing Record 3 of Set 17 | cidreira
# Processing Record 4 of Set 17 | ust-tsilma
# Processing Record 5 of Set 17 | pailon
# Processing Record 6 of Set 17 | rikitea
# Processing Record 7 of Set 17 | walvis bay
# Processing Record 8 of Set 17 | hambantota
# Processing Record 9 of Set 17 | hobart
# Processing Record 10 of Set 17 | sitka
# Processing Record 11 of Set 17 | mataura
# Processing Record 12 of Set 17 | shimoda
# Processing Record 13 of Set 17 | marovoay
# Processing Record 14 of Set 17 | talnakh
# Processing Record 15 of Set 17 | pevek
# Processing Record 16 of Set 17 | fairbanks
# Processing Record 17 of Set 17 | souillac
# Processing Record 18 of Set 17 | tuktoyaktuk
# Processing Record 19 of Set 17 | yellowknife
# Processing Record 20 of Set 17 | puerto escondido
# Processing Record 21 of Set 17 | kiunga
# Processing Record 22 of Set 17 | ossora
# Processing Record 23 of Set 17 | lagoa
# Processing Record 24 of Set 17 | talaya
# Processing Record 25 of Set 17 | lazaro cardenas
# Processing Record 26 of Set 17 | longyearbyen
# Processing Record 27 of Set 17 | palmer
# Processing Record 28 of Set 17 | fatsa
# Processing Record 29 of Set 17 | punta arenas
# Processing Record 30 of Set 17 | komsomolskiy
# Processing Record 31 of Set 17 | pangoa
# Processing Record 32 of Set 17 | luderitz
# Processing Record 33 of Set 17 | guanica
# Processing Record 34 of Set 17 | port alfred
# Processing Record 35 of Set 17 | jamestown
# Processing Record 36 of Set 17 | teahupoo
# Processing Record 37 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 17 | bengkulu
# Processing Record 39 of Set 17 | noyabrsk
# Processing Record 40 of Set 17 | arraial do cabo
# Processing Record 41 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 17 | stoyba
# City not found. Skipping...
# Processing Record 43 of Set 17 | pangnirtung
# Processing Record 44 of Set 17 | kousseri
# Processing Record 45 of Set 17 | airai
# Processing Record 46 of Set 17 | barra do garcas
# Processing Record 47 of Set 17 | saint-ambroise
# Processing Record 48 of Set 17 | blagoyevo
# Processing Record 49 of Set 17 | ngorongoro
# Processing Record 50 of Set 17 | prykolotne
# Processing Record 1 of Set 18 | skjervoy
# Processing Record 2 of Set 18 | rundu
# Processing Record 3 of Set 18 | lebu
# Processing Record 4 of Set 18 | ilulissat
# Processing Record 5 of Set 18 | hilo
# Processing Record 6 of Set 18 | leeuwarden
# Processing Record 7 of Set 18 | victoria
# Processing Record 8 of Set 18 | castro
# Processing Record 9 of Set 18 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 18 | valparaiso
# Processing Record 11 of Set 18 | beringovskiy
# Processing Record 12 of Set 18 | igurusi
# Processing Record 13 of Set 18 | butaritari
# Processing Record 14 of Set 18 | havelock
# Processing Record 15 of Set 18 | carauari
# Processing Record 16 of Set 18 | valdosta
# Processing Record 17 of Set 18 | mabaruma
# Processing Record 18 of Set 18 | tiznit
# Processing Record 19 of Set 18 | sao filipe
# Processing Record 20 of Set 18 | kuche
# City not found. Skipping...
# Processing Record 21 of Set 18 | torbay
# Processing Record 22 of Set 18 | revda
# Processing Record 23 of Set 18 | port elizabeth
# Processing Record 24 of Set 18 | barra do corda
# Processing Record 25 of Set 18 | dikson
# Processing Record 26 of Set 18 | palana
# Processing Record 27 of Set 18 | thompson
# Processing Record 28 of Set 18 | gat
# Processing Record 29 of Set 18 | chokurdakh
# Processing Record 30 of Set 18 | mount gambier
# Processing Record 31 of Set 18 | boa vista
# Processing Record 32 of Set 18 | cairns
# Processing Record 33 of Set 18 | edd
# Processing Record 34 of Set 18 | mlandizi
# Processing Record 35 of Set 18 | meulaboh
# Processing Record 36 of Set 18 | hunza
# City not found. Skipping...
# Processing Record 37 of Set 18 | saint-pierre
# Processing Record 38 of Set 18 | constitucion
# Processing Record 39 of Set 18 | srednekolymsk
# Processing Record 40 of Set 18 | severomuysk
# Processing Record 41 of Set 18 | roebourne
# Processing Record 42 of Set 18 | ozinki
# Processing Record 43 of Set 18 | shu
# Processing Record 44 of Set 18 | obihiro
# Processing Record 45 of Set 18 | trairi
# Processing Record 46 of Set 18 | shebunino
# Processing Record 47 of Set 18 | uglovka
# Processing Record 48 of Set 18 | kudat
# Processing Record 49 of Set 18 | tuatapere
# Processing Record 50 of Set 18 | sukhumi
# Processing Record 1 of Set 19 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 19 | nanortalik
# Processing Record 3 of Set 19 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 19 | portoferraio
# Processing Record 5 of Set 19 | yulara
# Processing Record 6 of Set 19 | belyy yar
# Processing Record 7 of Set 19 | hithadhoo
# Processing Record 8 of Set 19 | ijaki
# City not found. Skipping...
# Processing Record 9 of Set 19 | khatanga
# Processing Record 10 of Set 19 | singarayakonda
# Processing Record 11 of Set 19 | mar del plata
# Processing Record 12 of Set 19 | lhuntshi
# City not found. Skipping...
# Processing Record 13 of Set 19 | east london
# Processing Record 14 of Set 19 | salinopolis
# Processing Record 15 of Set 19 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 19 | bethel
# Processing Record 17 of Set 19 | thaba nchu
# Processing Record 18 of Set 19 | puerto ayora
# Processing Record 19 of Set 19 | aklavik
# Processing Record 20 of Set 19 | carnarvon
# Processing Record 21 of Set 19 | sept-iles
# Processing Record 22 of Set 19 | zhigansk
# Processing Record 23 of Set 19 | volchansk
# Processing Record 24 of Set 19 | san quintin
# Processing Record 25 of Set 19 | kirakira
# Processing Record 26 of Set 19 | ponta do sol
# Processing Record 27 of Set 19 | bose
# Processing Record 28 of Set 19 | rincon
# Processing Record 29 of Set 19 | skibbereen
# Processing Record 30 of Set 19 | hamilton
# Processing Record 31 of Set 19 | georgetown
# Processing Record 32 of Set 19 | waipawa
# Processing Record 33 of Set 19 | severo-kurilsk
# Processing Record 34 of Set 19 | katherine
# Processing Record 35 of Set 19 | verkhnyaya inta
# Processing Record 36 of Set 19 | vestmannaeyjar
# Processing Record 37 of Set 19 | salym
# Processing Record 38 of Set 19 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 19 | yar-sale
# Processing Record 40 of Set 19 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 19 | sindhnur
# Processing Record 42 of Set 19 | axim
# Processing Record 43 of Set 19 | kapaa
# Processing Record 44 of Set 19 | bereda
# Processing Record 45 of Set 19 | olafsvik
# Processing Record 46 of Set 19 | atuona
# Processing Record 47 of Set 19 | staryy krym
# Processing Record 48 of Set 19 | whitehorse
# Processing Record 49 of Set 19 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 19 | kazachinskoye
# Processing Record 1 of Set 20 | husavik
# Processing Record 2 of Set 20 | necochea
# Processing Record 3 of Set 20 | koutiala
# Processing Record 4 of Set 20 | iqaluit
# Processing Record 5 of Set 20 | salalah
# Processing Record 6 of Set 20 | polican
# Processing Record 7 of Set 20 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 20 | bathsheba
# Processing Record 9 of Set 20 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 20 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 20 | sault sainte marie
# Processing Record 12 of Set 20 | fort erie
# Processing Record 13 of Set 20 | esperance
# Processing Record 14 of Set 20 | antofagasta
# Processing Record 15 of Set 20 | kalabo
# Processing Record 16 of Set 20 | jizan
# Processing Record 17 of Set 20 | thinadhoo
# Processing Record 18 of Set 20 | riberalta
# Processing Record 19 of Set 20 | shingu
# Processing Record 20 of Set 20 | egvekinot
# Processing Record 21 of Set 20 | bambous virieux
# Processing Record 22 of Set 20 | tawang
# Processing Record 23 of Set 20 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 20 | poum
# Processing Record 25 of Set 20 | la ronge
# Processing Record 26 of Set 20 | upernavik
# Processing Record 27 of Set 20 | alepe
# Processing Record 28 of Set 20 | baie-comeau
# Processing Record 29 of Set 20 | sovetskaya gavan
# Processing Record 30 of Set 20 | avarua
# Processing Record 31 of Set 20 | nikolskoye
# Processing Record 32 of Set 20 | menongue
# Processing Record 33 of Set 20 | staryy nadym
# Processing Record 34 of Set 20 | korla
# Processing Record 35 of Set 20 | saskylakh
# Processing Record 36 of Set 20 | haines junction
# Processing Record 37 of Set 20 | karasjok
# Processing Record 38 of Set 20 | faanui
# Processing Record 39 of Set 20 | kalmar
# Processing Record 40 of Set 20 | vila franca do campo
# Processing Record 41 of Set 20 | port lincoln
# Processing Record 42 of Set 20 | tsentralnyy
# City not found. Skipping...
# Processing Record 43 of Set 20 | ancud
# Processing Record 44 of Set 20 | burayevo
# Processing Record 45 of Set 20 | semporna
# Processing Record 46 of Set 20 | sembakung
# Processing Record 47 of Set 20 | agadez
# Processing Record 48 of Set 20 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 20 | margate
# Processing Record 50 of Set 20 | vila velha
# Processing Record 1 of Set 21 | nipawin
# Processing Record 2 of Set 21 | robore
# Processing Record 3 of Set 21 | brae
# Processing Record 4 of Set 21 | rio gallegos
# Processing Record 5 of Set 21 | russell
# Processing Record 6 of Set 21 | barbar
# City not found. Skipping...
# Processing Record 7 of Set 21 | cherskiy
# Processing Record 8 of Set 21 | atambua
# Processing Record 9 of Set 21 | leh
# Processing Record 10 of Set 21 | coahuayana
# Processing Record 11 of Set 21 | ostrovnoy
# Processing Record 12 of Set 21 | naze
# Processing Record 13 of Set 21 | puerto madryn
# Processing Record 14 of Set 21 | adamas
# Processing Record 15 of Set 21 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 21 | sinnamary
# Processing Record 17 of Set 21 | vardo
# Processing Record 18 of Set 21 | englewood
# Processing Record 19 of Set 21 | novochernorechenskiy
# Processing Record 20 of Set 21 | pisco
# Processing Record 21 of Set 21 | terrace
# Processing Record 22 of Set 21 | penzance
# Processing Record 23 of Set 21 | fenoarivo
# Processing Record 24 of Set 21 | samarai
# Processing Record 25 of Set 21 | sobolevo
# Processing Record 26 of Set 21 | hovd
# Processing Record 27 of Set 21 | berbera
# Processing Record 28 of Set 21 | lao cai
# Processing Record 29 of Set 21 | kilmez
# City not found. Skipping...
# Processing Record 30 of Set 21 | sikonge
# Processing Record 31 of Set 21 | nsanje
# Processing Record 32 of Set 21 | san cristobal
# Processing Record 33 of Set 21 | alofi
# Processing Record 34 of Set 21 | magadi
# Processing Record 35 of Set 21 | spartanburg
# Processing Record 36 of Set 21 | hit
# Processing Record 37 of Set 21 | kedgwick
# Processing Record 38 of Set 21 | fortuna
# Processing Record 39 of Set 21 | stendal
# Processing Record 40 of Set 21 | ust-kuyga
# Processing Record 41 of Set 21 | polunochnoye
# Processing Record 42 of Set 21 | saldanha
# Processing Record 43 of Set 21 | jadu
# Processing Record 44 of Set 21 | bandarbeyla
# Processing Record 45 of Set 21 | shulan
# Processing Record 46 of Set 21 | port blair
# Processing Record 47 of Set 21 | haibowan
# City not found. Skipping...
# Processing Record 48 of Set 21 | kosonsoy
# Processing Record 49 of Set 21 | kasongo-lunda
# Processing Record 50 of Set 21 | the valley
# Processing Record 1 of Set 22 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 22 | envira
# Processing Record 3 of Set 22 | leningradskiy
# Processing Record 4 of Set 22 | kununurra
# Processing Record 5 of Set 22 | paamiut
# Processing Record 6 of Set 22 | ternate
# Processing Record 7 of Set 22 | xunchang
# Processing Record 8 of Set 22 | monrovia
# Processing Record 9 of Set 22 | bacalar
# Processing Record 10 of Set 22 | los llanos de aridane
# Processing Record 11 of Set 22 | tasiilaq
# Processing Record 12 of Set 22 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 22 | alice springs
# Processing Record 14 of Set 22 | grand gaube
# Processing Record 15 of Set 22 | phangnga
# Processing Record 16 of Set 22 | hofn
# Processing Record 17 of Set 22 | whitianga
# Processing Record 18 of Set 22 | mont-dore
# Processing Record 19 of Set 22 | jurm
# Processing Record 20 of Set 22 | semenivka
# Processing Record 21 of Set 22 | nizhniy kuranakh
# Processing Record 22 of Set 22 | madang
# Processing Record 23 of Set 22 | vostok
# Processing Record 24 of Set 22 | cabrera
# Processing Record 25 of Set 22 | panacan
# Processing Record 26 of Set 22 | teberda
# Processing Record 27 of Set 22 | ahuimanu
# Processing Record 28 of Set 22 | nueva gorgona
# Processing Record 29 of Set 22 | roanoke rapids
# Processing Record 30 of Set 22 | satuk
# Processing Record 31 of Set 22 | buala
# Processing Record 32 of Set 22 | malanje
# Processing Record 33 of Set 22 | riyadh
# Processing Record 34 of Set 22 | meridian
# Processing Record 35 of Set 22 | cabedelo
# Processing Record 36 of Set 22 | miles city
# Processing Record 37 of Set 22 | alekseyevsk
# Processing Record 38 of Set 22 | urumqi
# Processing Record 39 of Set 22 | batemans bay
# Processing Record 40 of Set 22 | saiha
# Processing Record 41 of Set 22 | yershov
# Processing Record 42 of Set 22 | anadyr
# Processing Record 43 of Set 22 | dalvik
# Processing Record 44 of Set 22 | kamalganj
# Processing Record 45 of Set 22 | saint stephen
# Processing Record 46 of Set 22 | tautira
# Processing Record 47 of Set 22 | zyryanovsk
# Processing Record 48 of Set 22 | namibe
# Processing Record 49 of Set 22 | asfi
# Processing Record 50 of Set 22 | bystryy istok
# Processing Record 1 of Set 23 | khasan
# Processing Record 2 of Set 23 | neiafu
# Processing Record 3 of Set 23 | kamnik
# Processing Record 4 of Set 23 | flinders
# Processing Record 5 of Set 23 | mahebourg
# Processing Record 6 of Set 23 | talon
# Processing Record 7 of Set 23 | sosnovo-ozerskoye
# Processing Record 8 of Set 23 | bang saphan
# Processing Record 9 of Set 23 | carnot
# Processing Record 10 of Set 23 | sarai
# Processing Record 11 of Set 23 | hearst
# Processing Record 12 of Set 23 | saint george
# Processing Record 13 of Set 23 | buin
# Processing Record 14 of Set 23 | uspenka
# Processing Record 15 of Set 23 | bembereke
# Processing Record 16 of Set 23 | chepareria
# Processing Record 17 of Set 23 | kaeo
# Processing Record 18 of Set 23 | vao
# Processing Record 19 of Set 23 | nelson bay
# Processing Record 20 of Set 23 | lorengau
# Processing Record 21 of Set 23 | parrita
# Processing Record 22 of Set 23 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 23 | scarborough
# Processing Record 24 of Set 23 | kavieng
# Processing Record 25 of Set 23 | mandera
# Processing Record 26 of Set 23 | dom pedrito
# Processing Record 27 of Set 23 | isangel
# Processing Record 28 of Set 23 | atbasar
# Processing Record 29 of Set 23 | hudson bay
# Processing Record 30 of Set 23 | basco
# Processing Record 31 of Set 23 | izazi
# Processing Record 32 of Set 23 | barabinsk
# Processing Record 33 of Set 23 | urengoy
# Processing Record 34 of Set 23 | jumla
# Processing Record 35 of Set 23 | mata
# Processing Record 36 of Set 23 | merauke
# Processing Record 37 of Set 23 | amalapuram
# Processing Record 38 of Set 23 | susanville
# Processing Record 39 of Set 23 | maryborough
# Processing Record 40 of Set 23 | jasper
# Processing Record 41 of Set 23 | shenjiamen
# Processing Record 42 of Set 23 | chapais
# Processing Record 43 of Set 23 | mutis
# Processing Record 44 of Set 23 | praia da vitoria
# Processing Record 45 of Set 23 | jining
# Processing Record 46 of Set 23 | pangody
# Processing Record 47 of Set 23 | garowe
# Processing Record 48 of Set 23 | kruisfontein
# Processing Record 49 of Set 23 | talakan
# Processing Record 50 of Set 23 | jiddah
# City not found. Skipping...
# Processing Record 1 of Set 24 | ketchikan
# Processing Record 2 of Set 24 | manuk mangkaw
# Processing Record 3 of Set 24 | dukat
# Processing Record 4 of Set 24 | grand baie
# Processing Record 5 of Set 24 | itoman
# Processing Record 6 of Set 24 | bambanglipuro
# Processing Record 7 of Set 24 | dorado
# Processing Record 8 of Set 24 | saint anthony
# Processing Record 9 of Set 24 | celestun
# Processing Record 10 of Set 24 | dubuque
# Processing Record 11 of Set 24 | murgab
# Processing Record 12 of Set 24 | tommot
# Processing Record 13 of Set 24 | saint-paul
# Processing Record 14 of Set 24 | shepetivka
# Processing Record 15 of Set 24 | senador guiomard
# Processing Record 16 of Set 24 | kushima
# Processing Record 17 of Set 24 | wanning
# Processing Record 18 of Set 24 | saint-joseph
# Processing Record 19 of Set 24 | marsh harbour
# Processing Record 20 of Set 24 | pangkalanbuun
# Processing Record 21 of Set 24 | aguimes
# Processing Record 22 of Set 24 | huaraz
# Processing Record 23 of Set 24 | virovitica
# Processing Record 24 of Set 24 | smithers
# Processing Record 25 of Set 24 | oum hadjer
# Processing Record 26 of Set 24 | simao
# Processing Record 27 of Set 24 | kargat
# Processing Record 28 of Set 24 | arlit
# Processing Record 29 of Set 24 | agropoli
# Processing Record 30 of Set 24 | tabou
# Processing Record 31 of Set 24 | ghanzi
# Processing Record 32 of Set 24 | raudeberg
# Processing Record 33 of Set 24 | namtsy
# Processing Record 34 of Set 24 | sal rei
# Processing Record 35 of Set 24 | high level
# Processing Record 36 of Set 24 | yuzha
# Processing Record 37 of Set 24 | kahului
# Processing Record 38 of Set 24 | majene
# Processing Record 39 of Set 24 | caravelas
# Processing Record 40 of Set 24 | nome
# Processing Record 41 of Set 24 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 24 | bima
# Processing Record 43 of Set 24 | coquimbo
# Processing Record 44 of Set 24 | san juan
# Processing Record 45 of Set 24 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 24 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 24 | san carlos de bariloche
# Processing Record 48 of Set 24 | wad madani
# Processing Record 49 of Set 24 | honningsvag
# Processing Record 50 of Set 24 | sladkovo
# Processing Record 1 of Set 25 | nicolas bravo
# Processing Record 2 of Set 25 | lavrentiya
# Processing Record 3 of Set 25 | kushiro
# Processing Record 4 of Set 25 | cayenne
# Processing Record 5 of Set 25 | avera
# Processing Record 6 of Set 25 | kushmurun
# Processing Record 7 of Set 25 | novyy urengoy
# Processing Record 8 of Set 25 | longlac
# City not found. Skipping...
# Processing Record 9 of Set 25 | newport
# Processing Record 10 of Set 25 | vestmanna
# Processing Record 11 of Set 25 | gillette
# Processing Record 12 of Set 25 | liberal
# Processing Record 13 of Set 25 | ulladulla
# Processing Record 14 of Set 25 | laguna
# Processing Record 15 of Set 25 | inuvik
# Processing Record 16 of Set 25 | lompoc
# Processing Record 17 of Set 25 | beyneu
# Processing Record 18 of Set 25 | waitati
# Processing Record 19 of Set 25 | cabildo
# Processing Record 20 of Set 25 | burns lake
# Processing Record 21 of Set 25 | zeya
# Processing Record 22 of Set 25 | ashland
# Processing Record 23 of Set 25 | ipixuna
# Processing Record 24 of Set 25 | kamina
# Processing Record 25 of Set 25 | aroeiras
# Processing Record 26 of Set 25 | boffa
# Processing Record 27 of Set 25 | cabo san lucas
# Processing Record 28 of Set 25 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 25 | hirara
# Processing Record 30 of Set 25 | pemangkat
# Processing Record 31 of Set 25 | culasian
# Processing Record 32 of Set 25 | popondetta
# Processing Record 33 of Set 25 | kumluca
# Processing Record 34 of Set 25 | akureyri
# Processing Record 35 of Set 25 | uppsala
# Processing Record 36 of Set 25 | cancun
# Processing Record 37 of Set 25 | turan
# Processing Record 38 of Set 25 | shiyan
# Processing Record 39 of Set 25 | okhotsk
# Processing Record 40 of Set 25 | lazarev
# Processing Record 41 of Set 25 | san patricio
# Processing Record 42 of Set 25 | umm kaddadah
# Processing Record 43 of Set 25 | synya
# Processing Record 44 of Set 25 | makrikapa
# City not found. Skipping...
# Processing Record 45 of Set 25 | schonebeck
# Processing Record 46 of Set 25 | lata
# Processing Record 47 of Set 25 | mount isa
# Processing Record 48 of Set 25 | sanmenxia
# Processing Record 49 of Set 25 | kijang
# Processing Record 50 of Set 25 | kathmandu
# Processing Record 1 of Set 26 | tilichiki
# Processing Record 2 of Set 26 | chimbote
# Processing Record 3 of Set 26 | zhaotong
# Processing Record 4 of Set 26 | yaan
# Processing Record 5 of Set 26 | hun
# Processing Record 6 of Set 26 | zaraza
# Processing Record 7 of Set 26 | rapid valley
# Processing Record 8 of Set 26 | anshun
# Processing Record 9 of Set 26 | mezdra
# Processing Record 10 of Set 26 | pangai
# Processing Record 11 of Set 26 | chiaravalle
# Processing Record 12 of Set 26 | valera
# Processing Record 13 of Set 26 | verkhnevilyuysk
# Processing Record 14 of Set 26 | aksu
# Processing Record 15 of Set 26 | bandiagara
# Processing Record 16 of Set 26 | sioux lookout
# Processing Record 17 of Set 26 | moindou
# Processing Record 18 of Set 26 | ashington
# Processing Record 19 of Set 26 | buchanan
# Processing Record 20 of Set 26 | sheridan
# Processing Record 21 of Set 26 | richards bay
# Processing Record 22 of Set 26 | tabasco
# Processing Record 23 of Set 26 | atyashevo
# Processing Record 24 of Set 26 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 26 | anuchino
# Processing Record 26 of Set 26 | mastung
# Processing Record 27 of Set 26 | buraydah
# Processing Record 28 of Set 26 | saint-francois
# Processing Record 29 of Set 26 | lichuan
# Processing Record 30 of Set 26 | temaraia
# City not found. Skipping...
# Processing Record 31 of Set 26 | napierville
# Processing Record 32 of Set 26 | salon-de-provence
# Processing Record 33 of Set 26 | didao
# Processing Record 34 of Set 26 | labuhan
# Processing Record 35 of Set 26 | marfino
# Processing Record 36 of Set 26 | kurumkan
# Processing Record 37 of Set 26 | cherdyn
# Processing Record 38 of Set 26 | seminole
# Processing Record 39 of Set 26 | ikongo
# Processing Record 40 of Set 26 | narsaq
# Processing Record 41 of Set 26 | soroca
# Processing Record 42 of Set 26 | sidi ali
# Processing Record 43 of Set 26 | vallenar
# Processing Record 44 of Set 26 | shalinskoye
# Processing Record 45 of Set 26 | lalmanir hat
# City not found. Skipping...
# Processing Record 46 of Set 26 | bloomfield
# Processing Record 47 of Set 26 | seesen
# Processing Record 48 of Set 26 | yining
# Processing Record 49 of Set 26 | krasnoselkup
# Processing Record 50 of Set 26 | ambon
# Processing Record 1 of Set 27 | muros
# Processing Record 2 of Set 27 | kudahuvadhoo
# Processing Record 3 of Set 27 | carmen
# Processing Record 4 of Set 27 | flin flon
# Processing Record 5 of Set 27 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 27 | erattupetta
# Processing Record 7 of Set 27 | brewster
# Processing Record 8 of Set 27 | cruz
# Processing Record 9 of Set 27 | pimentel
# Processing Record 10 of Set 27 | yatou
# Processing Record 11 of Set 27 | guilin
# Processing Record 12 of Set 27 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 27 | northam
# Processing Record 14 of Set 27 | charters towers
# Processing Record 15 of Set 27 | kati
# Processing Record 16 of Set 27 | kutum
# Processing Record 17 of Set 27 | ahipara
# Processing Record 18 of Set 27 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 27 | burica
# City not found. Skipping...
# Processing Record 20 of Set 27 | tourlaville
# Processing Record 21 of Set 27 | bonavista
# Processing Record 22 of Set 27 | borovoy
# Processing Record 23 of Set 27 | minab
# Processing Record 24 of Set 27 | beberibe
# Processing Record 25 of Set 27 | kalawit
# Processing Record 26 of Set 27 | umkomaas
# Processing Record 27 of Set 27 | rivera
# Processing Record 28 of Set 27 | dolneni
# Processing Record 29 of Set 27 | luanda
# Processing Record 30 of Set 27 | nhulunbuy
# Processing Record 31 of Set 27 | sola
# Processing Record 32 of Set 27 | domingos martins
# Processing Record 33 of Set 27 | yarkovo
# Processing Record 34 of Set 27 | naberera
# Processing Record 35 of Set 27 | cururupu
# Processing Record 36 of Set 27 | tombouctou
# Processing Record 37 of Set 27 | aripuana
# Processing Record 38 of Set 27 | le vauclin
# Processing Record 39 of Set 27 | bandar-e lengeh
# Processing Record 40 of Set 27 | matara
# Processing Record 41 of Set 27 | omboue
# Processing Record 42 of Set 27 | talara
# Processing Record 43 of Set 27 | fereydun kenar
# Processing Record 44 of Set 27 | gimli
# Processing Record 45 of Set 27 | saint-leu
# Processing Record 46 of Set 27 | kavaratti
# Processing Record 47 of Set 27 | malbork
# Processing Record 48 of Set 27 | namatanai
# Processing Record 49 of Set 27 | manokwari
# Processing Record 50 of Set 27 | okha
# Processing Record 1 of Set 28 | debre tabor
# Processing Record 2 of Set 28 | otradnoye
# Processing Record 3 of Set 28 | wuwei
# Processing Record 4 of Set 28 | chhatak
# Processing Record 5 of Set 28 | vershino-darasunskiy
# Processing Record 6 of Set 28 | brasilia
# Processing Record 7 of Set 28 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 28 | port-cartier
# Processing Record 9 of Set 28 | marapanim
# Processing Record 10 of Set 28 | geraldton
# Processing Record 11 of Set 28 | karasuk
# Processing Record 12 of Set 28 | elizabeth city
# Processing Record 13 of Set 28 | huacho
# Processing Record 14 of Set 28 | bathurst
# Processing Record 15 of Set 28 | sibolga
# Processing Record 16 of Set 28 | poronaysk
# Processing Record 17 of Set 28 | inta
# Processing Record 18 of Set 28 | svobodnyy
# Processing Record 19 of Set 28 | aykhal
# Processing Record 20 of Set 28 | pochutla
# Processing Record 21 of Set 28 | viligili
# City not found. Skipping...
# Processing Record 22 of Set 28 | catuday
# Processing Record 23 of Set 28 | chokwe
# Processing Record 24 of Set 28 | tessalit
# Processing Record 25 of Set 28 | pacific grove
# Processing Record 26 of Set 28 | harper
# Processing Record 27 of Set 28 | grindavik
# Processing Record 28 of Set 28 | quatre cocos
# Processing Record 29 of Set 28 | dingle
# Processing Record 30 of Set 28 | tres arroyos
# Processing Record 31 of Set 28 | salem
# Processing Record 32 of Set 28 | skagastrond
# City not found. Skipping...
# Processing Record 33 of Set 28 | baikunthpur
# Processing Record 34 of Set 28 | marystown
# Processing Record 35 of Set 28 | mutsamudu
# City not found. Skipping...
# Processing Record 36 of Set 28 | rawson
# Processing Record 37 of Set 28 | marawi
# Processing Record 38 of Set 28 | comodoro rivadavia
# Processing Record 39 of Set 28 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 28 | salinas
# Processing Record 41 of Set 28 | cartagena
# Processing Record 42 of Set 28 | kalakamati
# Processing Record 43 of Set 28 | xinqing
# Processing Record 44 of Set 28 | puerto ayacucho
# Processing Record 45 of Set 28 | muroto
# Processing Record 46 of Set 28 | alta floresta
# Processing Record 47 of Set 28 | iisalmi
# Processing Record 48 of Set 28 | seymchan
# Processing Record 49 of Set 28 | chickasha
# Processing Record 50 of Set 28 | gizo
# Processing Record 1 of Set 29 | khorixas
# Processing Record 2 of Set 29 | tornio
# Processing Record 3 of Set 29 | auki
# Processing Record 4 of Set 29 | calatagan
# Processing Record 5 of Set 29 | marolambo
# Processing Record 6 of Set 29 | stornoway
# Processing Record 7 of Set 29 | porbandar
# Processing Record 8 of Set 29 | sinkat
# City not found. Skipping...
# Processing Record 9 of Set 29 | clyde river
# Processing Record 10 of Set 29 | patacamaya
# Processing Record 11 of Set 29 | kropotkin
# Processing Record 12 of Set 29 | paradwip
# City not found. Skipping...
# Processing Record 13 of Set 29 | havre
# Processing Record 14 of Set 29 | newala
# Processing Record 15 of Set 29 | havre-saint-pierre
# Processing Record 16 of Set 29 | grand-santi
# Processing Record 17 of Set 29 | mecca
# Processing Record 18 of Set 29 | cockburn harbour
# City not found. Skipping...
# Processing Record 19 of Set 29 | batticaloa
# Processing Record 20 of Set 29 | bellinzona
# Processing Record 21 of Set 29 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 29 | banjar
# Processing Record 23 of Set 29 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 29 | rafsanjan
# Processing Record 25 of Set 29 | verkhnetulomskiy
# Processing Record 26 of Set 29 | stolin
# Processing Record 27 of Set 29 | lakes entrance
# Processing Record 28 of Set 29 | nioki
# Processing Record 29 of Set 29 | ambovombe
# Processing Record 30 of Set 29 | zhezkazgan
# Processing Record 31 of Set 29 | coihaique
# Processing Record 32 of Set 29 | porto velho
# Processing Record 33 of Set 29 | soyo
# Processing Record 34 of Set 29 | aldan
# Processing Record 35 of Set 29 | nicoya
# Processing Record 36 of Set 29 | guerrero negro
# Processing Record 37 of Set 29 | khani
# Processing Record 38 of Set 29 | nastola
# Processing Record 39 of Set 29 | mananara
# Processing Record 40 of Set 29 | ayorou
# Processing Record 41 of Set 29 | kungurtug
# Processing Record 42 of Set 29 | belmonte
# Processing Record 43 of Set 29 | emerald
# Processing Record 44 of Set 29 | naryan-mar
# Processing Record 45 of Set 29 | sao francisco do sul
# Processing Record 46 of Set 29 | kimbe
# Processing Record 47 of Set 29 | crab hill
# City not found. Skipping...
# Processing Record 48 of Set 29 | sainte-thecle
# Processing Record 49 of Set 29 | olinda
# Processing Record 50 of Set 29 | shestakovo
# Processing Record 1 of Set 30 | ulcinj
# Processing Record 2 of Set 30 | japura
# Processing Record 3 of Set 30 | kuching
# Processing Record 4 of Set 30 | wagar
# Processing Record 5 of Set 30 | sao felix do xingu
# Processing Record 6 of Set 30 | mayumba
# Processing Record 7 of Set 30 | conde
# Processing Record 8 of Set 30 | ballina
# Processing Record 9 of Set 30 | henties bay
# Processing Record 10 of Set 30 | san cosme y damian
# Processing Record 11 of Set 30 | ishigaki
# Processing Record 12 of Set 30 | dunedin
# Processing Record 13 of Set 30 | rafaela
# Processing Record 14 of Set 30 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 30 | havoysund
# Processing Record 16 of Set 30 | glenwood springs
# Processing Record 17 of Set 30 | nantucket
# Processing Record 18 of Set 30 | nyurba
# Processing Record 19 of Set 30 | santa maria
# Processing Record 20 of Set 30 | challapata
# Processing Record 21 of Set 30 | sisimiut
# Processing Record 22 of Set 30 | ordzhonikidze
# Processing Record 23 of Set 30 | emmaus
# Processing Record 24 of Set 30 | karratha
# Processing Record 25 of Set 30 | andenes
# Processing Record 26 of Set 30 | longkou
# Processing Record 27 of Set 30 | ningan
# City not found. Skipping...
# Processing Record 28 of Set 30 | cabra
# Processing Record 29 of Set 30 | clermont
# Processing Record 30 of Set 30 | tawkar
# City not found. Skipping...
# Processing Record 31 of Set 30 | luganville
# Processing Record 32 of Set 30 | tipperary
# Processing Record 33 of Set 30 | chimbarongo
# Processing Record 34 of Set 30 | piacabucu
# Processing Record 35 of Set 30 | talcahuano
# Processing Record 36 of Set 30 | kitimat
# Processing Record 37 of Set 30 | lucea
# Processing Record 38 of Set 30 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 30 | santa catalina
# Processing Record 40 of Set 30 | port-gentil
# Processing Record 41 of Set 30 | viedma
# Processing Record 42 of Set 30 | porto novo
# Processing Record 43 of Set 30 | vakhtan
# Processing Record 44 of Set 30 | bubaque
# Processing Record 45 of Set 30 | kleck
# City not found. Skipping...
# Processing Record 46 of Set 30 | yanam
# Processing Record 47 of Set 30 | livingston
# Processing Record 48 of Set 30 | deputatskiy
# Processing Record 49 of Set 30 | vera cruz
# Processing Record 50 of Set 30 | tarko-sale
# Processing Record 1 of Set 31 | dawson
# Processing Record 2 of Set 31 | moose factory
# Processing Record 3 of Set 31 | ola
# Processing Record 4 of Set 31 | juba
# Processing Record 5 of Set 31 | alugan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Te Anau -45.4167  167.7167     46.85        92          21        2.30
# 1      Ushuaia -54.8000  -68.3000     44.26        81          40       23.02
# 2       Nabire  -3.3667  135.4833     75.56        93         100        3.74
# 3       Hasaki  35.7333  140.8333     50.40        73         100       20.58
# 4  Derzhavinsk  51.1000   66.3167     50.81        68          47       11.68
#
#   Country Weather Description
# 0      NZ          few clouds
# 1      AR    scattered clouds
# 2      ID     overcast clouds
# 3      JP     overcast clouds
# 4      KZ    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "weatherpy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
